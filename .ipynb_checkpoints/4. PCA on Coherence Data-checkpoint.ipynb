# %% [markdown]
# # PCA on Coherence Data
# Principal component analysis (PCA) can be used to reduce the dimensionality of a data set and can be helpful to visualize patterns, or clusters, in the underlying data.  This notebook will describe how we used PCA to visualize the "state" of a mouse overtime.

# %% [markdown]
# ## Extracting data from NeuroExplorer
#
# This process is much like what is used for plotting coherence for a single time bin; our NeuroExplorer template `coherence_4_tetrodes.ntp` is still used, but the script `coherence_4_tetrodes_overtime.py` applies it many times over a given recording for smaller chunks of data.  The output is a "superfolder" with subfolders corresponding to each time bin, all filled with `.csv` files of the coherence data.
#
# The example data used in this notebook was generated using the following steps:
# 1. Open the recording data file (from Plexon) in NeuroExplorer.  **All the LFPs are labeled using "FP##"** (this is how the code finds them).
# <img src="img/nex_lfps.png">
# 2. Open the script `coherence_4_tetrodes_overtime.py` in NeuroExplorer's IDE.
# 3. Within the "parameters" section of the script, make sure the `template` variable points to the template `coherence_4_tetrodes`.  Double check that all other settings are appropriate.  The `bin_size` argument is what determines the output frequency.
# <img src="img/coherence_4_tetrodes_overtime_screenshot.png">
# 4.  Run the script!
#
# The output of this process is the folder `coherence overtime plot data` within the `exampledata` folder.  The example was generated from a recording of an animal with two 16-channel arrays, one in  the orbitofrontal cortex (OFC) and one in the dorsomedial striatum (DMS).  This mouse was given an i.p. injection of cocaine partway through the recording.
#
# Note that the script will try to write a `movement.csv` file using a variable "Motion" which is based on mouse tracking data.  This may need to be removed or modified depending on if you have tracking data & how it is loaded into NeuroExplorer.
# <img src="img/motion_csv.png">

# %% [markdown]
# ## Computing PCs
#
# First we import `coherence.py`.

# %%
import coherence as co

# %% [markdown]
# Now, loading the data.  The goal is to generate a matrix where each row corresponds to a time bin and each column corresponds to the value of each principal component (PC) at that time.  To start, we can use `co.Coherence_1D_Overtime()`, which loads the data as a single _n\*k_  matrix, where _n_ is the number of time points and _k_ is the number of coherence connections.  In this case, with 32 wires there are 1024 coherence pairs (32\*32).
#
# At this point, we can select which wire pairs to include.  Passing no additional arguments to `co.Coherence_1D_Overtime()` will load every connection.  To slice the data, we can pass `co.Region()` instances as additional keyword arguments.  Below, I will select only the cells that correspond to coherence values between wires of the OFC and DMS.  As this intersecton constitutes only 16\*16 wires, this limits the data to 256 coherence values.
#
# As `co.Region()` objects in keyword arguments are used for slicing data, they are not used for labelling wires.  To do so, there is a `wirenames` argument which accepts a lists.  As the data will ultimately be converted to PCs, this step is not crucial.

# %%
#path to the data
data = r"exampledata\pca data"

#Region() objects for labelling wirenames
OFC = co.Region('OFC', range(1,16))
DMS = co.Region('DMS', range(17,32))

#Region() objects for slicing the data to run PCA on
OFC_DMS = co.Region('OFC-DMS', range(1,16), range(17,32))

#building the data
mouse1 = co.Coherence_1D_Overtime(data,
                                  band='gamma',
                                  wirenames=[OFC,DMS],
                                  ofc_dms=OFC_DMS)
# Out:
# ----------
#
# Trying to compute coherence data for "exampledata\pca data".
#
#
# Starting loop:
#
# exampledata\pca data\0_0-60 processed
# exampledata\pca data\1_60-120 processed
# exampledata\pca data\2_120-180 processed
# exampledata\pca data\3_180-240 processed
# exampledata\pca data\4_240-300 processed
# exampledata\pca data\5_300-360 processed
# exampledata\pca data\6_360-420 processed
# exampledata\pca data\7_420-480 processed
# exampledata\pca data\8_480-540 processed
# exampledata\pca data\9_540-600 processed
# exampledata\pca data\10_600-660 processed
# exampledata\pca data\11_660-720 processed
# exampledata\pca data\12_720-780 processed
# exampledata\pca data\13_780-840 processed
# exampledata\pca data\14_840-900 processed
# exampledata\pca data\15_900-960 processed
# exampledata\pca data\16_960-1020 processed
# exampledata\pca data\17_1020-1080 processed
# exampledata\pca data\18_1080-1140 processed
# exampledata\pca data\19_1140-1200 processed
# exampledata\pca data\20_1200-1260 processed
# exampledata\pca data\21_1260-1320 processed
# exampledata\pca data\22_1320-1380 processed
# exampledata\pca data\23_1380-1440 processed
# exampledata\pca data\24_1440-1500 processed
# exampledata\pca data\25_1500-1560 processed
# exampledata\pca data\26_1560-1620 processed
# exampledata\pca data\27_1620-1680 processed
# exampledata\pca data\28_1680-1740 processed
# exampledata\pca data\29_1740-1800 processed
# exampledata\pca data\30_1800-1860 processed
# exampledata\pca data\31_1860-1920 processed
# exampledata\pca data\32_1920-1980 processed
# exampledata\pca data\33_1980-2040 processed
# exampledata\pca data\34_2040-2100 processed
# exampledata\pca data\35_2100-2160 processed
# exampledata\pca data\36_2160-2220 processed
# exampledata\pca data\37_2220-2280 processed
# exampledata\pca data\38_2280-2340 processed
# exampledata\pca data\39_2340-2400 processed
# exampledata\pca data\40_2400-2460 processed
# exampledata\pca data\41_2460-2520 processed
# exampledata\pca data\42_2520-2580 processed
# exampledata\pca data\43_2580-2640 processed
# exampledata\pca data\44_2640-2700 processed
# exampledata\pca data\45_2700-2760 processed
# exampledata\pca data\46_2760-2820 processed
# exampledata\pca data\47_2820-2880 processed
# exampledata\pca data\48_2880-2940 processed
# exampledata\pca data\49_2940-3000 processed
# exampledata\pca data\50_3000-3060 processed
# exampledata\pca data\51_3060-3120 processed
# exampledata\pca data\52_3120-3180 processed
# exampledata\pca data\53_3180-3240 processed
# exampledata\pca data\54_3240-3300 processed
# exampledata\pca data\55_3300-3360 processed
# exampledata\pca data\56_3360-3420 processed
# exampledata\pca data\57_3420-3480 processed
# exampledata\pca data\58_3480-3540 processed
# exampledata\pca data\59_3540-3600 processed
# exampledata\pca data\60_3600-3660 processed
# exampledata\pca data\61_3660-3720 processed
# exampledata\pca data\62_3720-3780 processed
# exampledata\pca data\63_3780-3840 processed
# exampledata\pca data\64_3840-3900 processed
# exampledata\pca data\65_3900-3960 processed
# exampledata\pca data\66_3960-4020 processed
# exampledata\pca data\67_4020-4080 processed
# exampledata\pca data\68_4080-4140 processed
# exampledata\pca data\69_4140-4200 processed
# exampledata\pca data\70_4200-4260 processed
# exampledata\pca data\71_4260-4320 processed
# exampledata\pca data\72_4320-4380 processed
# exampledata\pca data\73_4380-4440 processed
# exampledata\pca data\74_4440-4500 processed
# exampledata\pca data\75_4500-4560 processed
# exampledata\pca data\76_4560-4620 processed
# exampledata\pca data\77_4620-4680 processed
# exampledata\pca data\78_4680-4740 processed
# exampledata\pca data\79_4740-4800 processed
# exampledata\pca data\80_4800-4860 processed
# exampledata\pca data\81_4860-4920 processed
# exampledata\pca data\82_4920-4980 processed
# exampledata\pca data\83_4980-5040 processed
# exampledata\pca data\84_5040-5100 processed
# exampledata\pca data\85_5100-5160 processed
# exampledata\pca data\86_5160-5220 processed
# exampledata\pca data\87_5220-5280 processed
# exampledata\pca data\88_5280-5340 processed
# exampledata\pca data\89_5340-5400 processed
# exampledata\pca data\90_5400-5460 processed
# exampledata\pca data\91_5460-5520 processed
# exampledata\pca data\92_5520-5580 processed
# exampledata\pca data\93_5580-5640 processed
# exampledata\pca data\94_5640-5700 processed
# exampledata\pca data\95_5700-5760 processed
# exampledata\pca data\96_5760-5820 processed
# exampledata\pca data\97_5820-5880 processed
# exampledata\pca data\98_5880-5940 processed
# exampledata\pca data\99_5940-6000 processed
# exampledata\pca data\100_6000-6060 processed
# exampledata\pca data\101_6060-6120 processed
# exampledata\pca data\102_6120-6180 processed
# exampledata\pca data\103_6180-6240 processed
# exampledata\pca data\104_6240-6300 processed
# exampledata\pca data\105_6300-6360 processed
# exampledata\pca data\106_6360-6420 processed
# exampledata\pca data\107_6420-6480 processed
# exampledata\pca data\108_6480-6540 processed
# exampledata\pca data\109_6540-6600 processed
# exampledata\pca data\110_6600-6660 processed
# exampledata\pca data\111_6660-6720 processed
# exampledata\pca data\112_6720-6780 processed
# exampledata\pca data\113_6780-6840 processed
# exampledata\pca data\114_6840-6900 processed
# exampledata\pca data\115_6900-6960 processed
# exampledata\pca data\116_6960-7020 processed
# exampledata\pca data\117_7020-7080 processed
# exampledata\pca data\118_7080-7140 processed
# exampledata\pca data\119_7140-7200 processed
# exampledata\pca data\120_7200-7260 processed
# exampledata\pca data\121_7260-7320 processed
# exampledata\pca data\122_7320-7380 processed
# exampledata\pca data\123_7380-7440 processed
# exampledata\pca data\124_7440-7500 processed
# exampledata\pca data\125_7500-7560 processed
# exampledata\pca data\126_7560-7620 processed
# exampledata\pca data\127_7620-7680 processed
# exampledata\pca data\128_7680-7740 processed
# exampledata\pca data\129_7740-7800 processed
# exampledata\pca data\130_7800-7860 processed
# exampledata\pca data\131_7860-7920 processed
# exampledata\pca data\132_7920-7980 processed
# exampledata\pca data\133_7980-8040 processed
# exampledata\pca data\134_8040-8100 processed
# exampledata\pca data\135_8100-8160 processed
# exampledata\pca data\136_8160-8220 processed
# exampledata\pca data\137_8220-8280 processed
# exampledata\pca data\138_8280-8340 processed
# exampledata\pca data\139_8340-8400 processed
# exampledata\pca data\140_8400-8460 processed
# exampledata\pca data\141_8460-8520 processed
# exampledata\pca data\142_8520-8580 processed
# exampledata\pca data\143_8580-8640 processed
# exampledata\pca data\144_8640-8700 processed
# exampledata\pca data\145_8700-8760 processed
# exampledata\pca data\146_8760-8820 processed
# exampledata\pca data\147_8820-8880 processed
# exampledata\pca data\148_8880-8940 processed
# exampledata\pca data\149_8940-9000 processed
# exampledata\pca data\150_9000-9060 processed
# exampledata\pca data\151_9060-9120 processed
# exampledata\pca data\152_9120-9180 processed
# exampledata\pca data\153_9180-9240 processed
# exampledata\pca data\154_9240-9300 processed
# exampledata\pca data\155_9300-9360 processed
# exampledata\pca data\156_9360-9420 processed
# exampledata\pca data\157_9420-9480 processed
# exampledata\pca data\158_9480-9540 processed
# exampledata\pca data\159_9540-9600 processed
# exampledata\pca data\160_9600-9660 processed
# exampledata\pca data\161_9660-9720 processed
# exampledata\pca data\162_9720-9780 processed
# exampledata\pca data\163_9780-9840 processed
# exampledata\pca data\164_9840-9900 processed
# exampledata\pca data\165_9900-9960 processed
# exampledata\pca data\166_9960-10020 processed
# exampledata\pca data\167_10020-10080 processed
#
# Merging data...
#
# Finished!
#
# Looking for .csv files in exampledata\pca data
#
# Loaded data from "info.csv"
#
#
# Loaded movement data from movement.csv

# %% [markdown]
# We can then examine the data to make sure they look correct.  Data are stored in the `data` attribute.

# %%
mouse1.data
# Out:
#           OFC 1 x DMS 1  OFC 1 x DMS 2  OFC 1 x DMS 3  OFC 1 x DMS 4  \
# Time (s)
# 0              0.168045       0.170505       0.050558       0.115753
# 60             0.162994       0.164879       0.059974       0.117410
# 120            0.202920       0.198888       0.063260       0.140494
# 180            0.182810       0.184016       0.057810       0.127873
# 240            0.212171       0.214963       0.059412       0.137354
# ...                 ...            ...            ...            ...
# 9780           0.310185       0.311365       0.067921       0.212299
# 9840           0.345877       0.345230       0.104867       0.256672
# 9900           0.324106       0.324253       0.090307       0.234148
# 9960           0.259926       0.253697       0.072139       0.189225
# 10020          0.266293       0.263429       0.068756       0.179991
#
#           OFC 1 x DMS 5  OFC 1 x DMS 6  OFC 1 x DMS 7  OFC 1 x DMS 8  \
# Time (s)
# 0              0.157081       0.141464       0.127838       0.151115
# 60             0.151464       0.140499       0.131674       0.148213
# 120            0.184583       0.172732       0.157392       0.178993
# 180            0.168543       0.156961       0.144433       0.164591
# 240            0.193016       0.182561       0.158348       0.181733
# ...                 ...            ...            ...            ...
# 9780           0.279566       0.273060       0.245438       0.277354
# 9840           0.315388       0.307178       0.287719       0.318096
# 9900           0.289779       0.287994       0.263653       0.293937
# 9960           0.243237       0.234478       0.217536       0.243765
# 10020          0.237256       0.232687       0.208672       0.233887
#
#           OFC 1 x DMS 9  OFC 1 x DMS 10  ...  OFC 16 x DMS 7  OFC 16 x DMS 8  \
# Time (s)                                 ...
# 0              0.102509        0.098048  ...        0.082834        0.092489
# 60             0.106430        0.101266  ...        0.075473        0.079240
# 120            0.131783        0.119906  ...        0.091321        0.101064
# 180            0.121090        0.112725  ...        0.079573        0.086056
# 240            0.132525        0.120838  ...        0.085065        0.092941
# ...                 ...             ...  ...             ...             ...
# 9780           0.213964        0.196059  ...        0.165293        0.185460
# 9840           0.252492        0.244791  ...        0.195752        0.217246
# 9900           0.225419        0.216471  ...        0.189640        0.209869
# 9960           0.181055        0.173328  ...        0.154477        0.173016
# 10020          0.181386        0.171151  ...        0.147359        0.162783
#
#           OFC 16 x DMS 9  OFC 16 x DMS 10  OFC 16 x DMS 11  OFC 16 x DMS 12  \
# Time (s)
# 0               0.069566         0.072520         0.086525         0.094866
# 60              0.060658         0.057887         0.082981         0.086146
# 120             0.080581         0.071940         0.101465         0.109545
# 180             0.064650         0.063205         0.090972         0.094760
# 240             0.074655         0.071092         0.096267         0.101924
# ...                  ...              ...              ...              ...
# 9780            0.144831         0.140918         0.189740         0.200007
# 9840            0.174866         0.173229         0.228877         0.233360
# 9900            0.164599         0.158901         0.210972         0.223975
# 9960            0.133163         0.132050         0.164370         0.183719
# 10020           0.129947         0.126396         0.163553         0.180307
#
#           OFC 16 x DMS 13  OFC 16 x DMS 14  OFC 16 x DMS 15  OFC 16 x DMS 16
# Time (s)
# 0                0.034536         0.074970         0.090931         0.098043
# 60               0.040518         0.074668         0.086981         0.089691
# 120              0.045679         0.091263         0.105504         0.112858
# 180              0.040720         0.081920         0.093625         0.099017
# 240              0.041089         0.088256         0.101361         0.106238
# ...                   ...              ...              ...              ...
# 9780             0.060769         0.180177         0.193423         0.206414
# 9840             0.074526         0.220527         0.235022         0.241128
# 9900             0.072586         0.200903         0.218970         0.227909
# 9960             0.049491         0.149877         0.176059         0.186312
# 10020            0.052109         0.151879         0.175017         0.183925
#
# [168 rows x 256 columns]

# %% [markdown]
# This matrix is properly formatted for running principal component analysis.  To compute PCs, we use the class `co.Coherence_PCA()`, which makes use of scikit-learn's `sklearn.decomposition.PCA`.  The second parameter is used to specify how many PCs to compute.

# %%
mouse1_pca = co.Coherence_PCA(mouse1, 10)
mouse1_pca.data
# Out:
#                PC1       PC2       PC3       PC4       PC5       PC6  \
# Time (s)
# 0         1.389207  0.016744 -0.187557  0.082760  0.049500  0.000222
# 60        1.489560  0.042657 -0.189598  0.072194  0.004314 -0.022107
# 120       1.025095 -0.075558 -0.118040  0.082264  0.031954  0.013887
# 180       1.360205  0.035392 -0.223695  0.109545 -0.013527 -0.049641
# 240       1.130813 -0.002651 -0.133938  0.116459 -0.019282 -0.009220
# ...            ...       ...       ...       ...       ...       ...
# 9780     -0.144388 -0.180587  0.053560 -0.092832  0.078795 -0.029147
# 9840     -0.701973 -0.065356  0.022981 -0.077231  0.087712 -0.024189
# 9900     -0.446449 -0.175022  0.075398 -0.141140  0.139184 -0.007503
# 9960      0.206556 -0.181103  0.015182 -0.127967  0.077549 -0.011186
# 10020     0.331293 -0.165113  0.033910 -0.125521  0.073151 -0.030709
#
#                PC7       PC8       PC9      PC10
# Time (s)
# 0        -0.007116 -0.003037  0.042593 -0.007973
# 60       -0.009960 -0.002842  0.037103 -0.012261
# 120       0.013087 -0.010949  0.007608 -0.010003
# 180       0.018093 -0.016293  0.052991  0.037080
# 240      -0.008136 -0.015084 -0.001189  0.031404
# ...            ...       ...       ...       ...
# 9780     -0.027594 -0.049677  0.038119  0.008943
# 9840      0.008592 -0.001312  0.008870  0.031761
# 9900      0.011009 -0.058991 -0.019798  0.030800
# 9960      0.008266 -0.027089 -0.011306 -0.002761
# 10020     0.039887 -0.037204 -0.009988  0.038612
#
# [168 rows x 10 columns]

# %% [markdown]
# ## Plotting
# With an instance of `co.Coherence_PCA`, there are built in methods for visualizing the data.

# %% [markdown]
# ### PCA line plot
# View the movement of the mouse through PCA space overtime.

# %%
plot = mouse1_pca.line_plot()

# %% [markdown]
# ### Limit the data with `Timeframe()`
# Instances of `co.Timeframe` can be passed to segment the plotted data.  In this case, we use them to show 30 minutes of data before and after cocaine was injected into this mouse.

# %%
pre = co.Timeframe(name='pre-cocaine',
                   start_sec=1200,
                   end_sec=3000,
                   color='blue')
post = co.Timeframe(name='post-cocaine',
                   start_sec=3700,
                   end_sec=5500,
                   color='red')

plot = mouse1_pca.line_plot(pre,post)

# %% [markdown]
# ### Plot a 2D Heatmap
# Using `kdeplot` from seaborn.

# %%
plot = mouse1_pca.heatmap(pre,post)

# %% [markdown]
# ### Show the explained varaince ratio

# %%
plot = mouse1_pca.scree_plot()

# %% [markdown]
# ### Animated line plot
#
# Animations can be saved used the `save` method:
# ```
# mouse1_pca.animated_line_plot(pre,post).save('my animation.gif', dpi=300)
# ```

# %%
plot = mouse1_pca.animated_line_plot(pre,post)
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
#using Ipython.display to render the gif in the notebook
from IPython.display import Image

with open(r'img/pca animation.gif','rb') as f:
    display(Image(data=f.read(), format='png'))

# %% [markdown]
# # Updates/Bugs
#
# *nothing to say here yet!*
